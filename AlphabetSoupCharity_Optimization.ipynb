# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df_clean = application_df.drop(columns=["EIN", "NAME"])

# %%
# Determine the number of unique values in each column.
for column in application_df_clean.columns:
    print(f"{column} has {application_df_clean[column].nunique()} unique values")
# Out:
# APPLICATION_TYPE has 17 unique values
# AFFILIATION has 6 unique values
# CLASSIFICATION has 71 unique values
# USE_CASE has 5 unique values
# ORGANIZATION has 4 unique values
# STATUS has 2 unique values
# INCOME_AMT has 9 unique values
# SPECIAL_CONSIDERATIONS has 2 unique values
# ASK_AMT has 8747 unique values
# IS_SUCCESSFUL has 2 unique values

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df_clean["APPLICATION_TYPE"].value_counts()
print(application_counts)
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff = 500
application_types_to_replace = application_counts[application_counts < cutoff].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df_clean['APPLICATION_TYPE'] = application_df_clean['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df_clean['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df_clean["CLASSIFICATION"].value_counts()
print(classification_counts)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts[classification_counts > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff = 1000
classifications_to_replace = classification_counts[classification_counts < cutoff].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df_numeric = pd.get_dummies(application_df_clean, columns=["APPLICATION_TYPE",
                                                                       "AFFILIATION",
                                                                       "CLASSIFICATION",
                                                                       "USE_CASE",
                                                                       "ORGANIZATION",
                                                                       "INCOME_AMT",
                                                                       "SPECIAL_CONSIDERATIONS"])

# %%
# Split our preprocessed data into our features and target arrays
X = application_df_numeric.drop(columns=["IS_SUCCESSFUL"])
y = application_df_numeric["IS_SUCCESSFUL"]

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=X_train_scaled.shape[1]))

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                8720
#
#  dense_1 (Dense)             (None, 80)                6480
#
#  dense_2 (Dense)             (None, 80)                6480
#
#  dense_3 (Dense)             (None, 1)                 81
#
# =================================================================
# Total params: 21761 (85.00 KB)
# Trainable params: 21761 (85.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
train_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 3ms/step - loss: 0.5701 - accuracy: 0.7245
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5517 - accuracy: 0.7316
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5483 - accuracy: 0.7353
# Epoch 4/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5456 - accuracy: 0.7348
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5449 - accuracy: 0.7363
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5449 - accuracy: 0.7359
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5433 - accuracy: 0.7359
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.7357
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7364
# Epoch 10/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5420 - accuracy: 0.7376
# Epoch 11/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5406 - accuracy: 0.7377
# Epoch 12/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5401 - accuracy: 0.7375
# Epoch 13/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5398 - accuracy: 0.7385
# Epoch 14/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5392 - accuracy: 0.7397
# Epoch 15/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5381 - accuracy: 0.7386
# Epoch 16/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5381 - accuracy: 0.7397
# Epoch 17/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5379 - accuracy: 0.7401
# Epoch 18/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5374 - accuracy: 0.7386
# Epoch 19/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5370 - accuracy: 0.7392
# Epoch 20/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5364 - accuracy: 0.7397
# Epoch 21/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5366 - accuracy: 0.7399
# Epoch 22/100
# 804/804 [==============================] - 4s 6ms/step - loss: 0.5355 - accuracy: 0.7402
# Epoch 23/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5359 - accuracy: 0.7399
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7402
# Epoch 25/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5348 - accuracy: 0.7400
# Epoch 26/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5341 - accuracy: 0.7401
# Epoch 27/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5342 - accuracy: 0.7413
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5339 - accuracy: 0.7406
# Epoch 29/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5342 - accuracy: 0.7409
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7411
# Epoch 31/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5336 - accuracy: 0.7406
# Epoch 32/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5332 - accuracy: 0.7415
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7419
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7415
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7412
# Epoch 36/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5324 - accuracy: 0.7424
# Epoch 37/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5320 - accuracy: 0.7417
# Epoch 38/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5321 - accuracy: 0.7417
# Epoch 39/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5321 - accuracy: 0.7423
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7432
# Epoch 41/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5314 - accuracy: 0.7427
# Epoch 42/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5311 - accuracy: 0.7430
# Epoch 43/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5316 - accuracy: 0.7418
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7424
# Epoch 45/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5309 - accuracy: 0.7428
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7423
# Epoch 47/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5307 - accuracy: 0.7428
# Epoch 48/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5306 - accuracy: 0.7423
# Epoch 49/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5307 - accuracy: 0.7427
# Epoch 50/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5303 - accuracy: 0.7433
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5296 - accuracy: 0.7427
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5299 - accuracy: 0.7422
# Epoch 53/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5310 - accuracy: 0.7424
# Epoch 54/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5291 - accuracy: 0.7433
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5297 - accuracy: 0.7430
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5298 - accuracy: 0.7423
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5295 - accuracy: 0.7435
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5295 - accuracy: 0.7426
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5292 - accuracy: 0.7432
# Epoch 60/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5295 - accuracy: 0.7428
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5288 - accuracy: 0.7435
# Epoch 62/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5286 - accuracy: 0.7427
# Epoch 63/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5282 - accuracy: 0.7438
# Epoch 64/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5292 - accuracy: 0.7428
# Epoch 65/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5286 - accuracy: 0.7431
# Epoch 66/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5287 - accuracy: 0.7434
# Epoch 67/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5280 - accuracy: 0.7437
# Epoch 68/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5279 - accuracy: 0.7434
# Epoch 69/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5285 - accuracy: 0.7438
# Epoch 70/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5282 - accuracy: 0.7428
# Epoch 71/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5282 - accuracy: 0.7434
# Epoch 72/100
# 804/804 [==============================] - 7s 9ms/step - loss: 0.5280 - accuracy: 0.7431
# Epoch 73/100
# 804/804 [==============================] - 7s 8ms/step - loss: 0.5276 - accuracy: 0.7441
# Epoch 74/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5276 - accuracy: 0.7434
# Epoch 75/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5280 - accuracy: 0.7431
# Epoch 76/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5278 - accuracy: 0.7434
# Epoch 77/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5287 - accuracy: 0.7437
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5271 - accuracy: 0.7435
# Epoch 79/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5274 - accuracy: 0.7441
# Epoch 80/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5276 - accuracy: 0.7432
# Epoch 81/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5281 - accuracy: 0.7439
# Epoch 82/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5271 - accuracy: 0.7435
# Epoch 83/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5282 - accuracy: 0.7440
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5274 - accuracy: 0.7441
# Epoch 85/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5275 - accuracy: 0.7442
# Epoch 86/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5272 - accuracy: 0.7441
# Epoch 87/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5271 - accuracy: 0.7435
# Epoch 88/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5269 - accuracy: 0.7439
# Epoch 89/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5273 - accuracy: 0.7443
# Epoch 90/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5287 - accuracy: 0.7439
# Epoch 91/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5268 - accuracy: 0.7437
# Epoch 92/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5268 - accuracy: 0.7448
# Epoch 93/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5269 - accuracy: 0.7445
# Epoch 94/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5264 - accuracy: 0.7442
# Epoch 95/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5268 - accuracy: 0.7440
# Epoch 96/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5266 - accuracy: 0.7441
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5263 - accuracy: 0.7442
# Epoch 98/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5263 - accuracy: 0.7444
# Epoch 99/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5267 - accuracy: 0.7442
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5261 - accuracy: 0.7442

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5807 - accuracy: 0.7256 - 400ms/epoch - 1ms/step
# Loss: 0.5807377696037292, Accuracy: 0.7255976796150208

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")

# %%
# Adjust the data
application_df_clean = application_df.drop(columns=['EIN', 'SPECIAL_CONSIDERATIONS'])

# Calculate value counts for the NAME column
name_counts = application_df['NAME'].value_counts()

# Determine which values to replace
names_to_replace = name_counts[name_counts < 5].index

# Replace in DataFrame
for name in names_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(name, "Other")

# %%
# Adjust cutoff for binning
cutoff = 200
application_counts = application_df_clean['APPLICATION_TYPE'].value_counts()
application_types_to_replace = application_counts[application_counts < cutoff].index.tolist()

for app in application_types_to_replace:
    application_df_clean['APPLICATION_TYPE'] = application_df_clean['APPLICATION_TYPE'].replace(app, "Other")
